# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_superstore.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           0       1  US-2023-103800  2023-01-03  2023-01-07  Standard Class
# 1           1       2  US-2023-112326  2023-01-04  2023-01-08  Standard Class
# 2           2       3  US-2023-112326  2023-01-04  2023-01-08  Standard Class
# 3           3       4  US-2023-112326  2023-01-04  2023-01-08  Standard Class
# 4           4       5  US-2023-141817  2023-01-05  2023-01-12  Standard Class
#
#   Customer ID  Customer Name      Segment Country/Region  ... Postal Code  \
# 0    DP-13000  Darren Powers     Consumer  United States  ...       77095
# 1    PO-19195  Phillina Ober  Home Office  United States  ...       60540
# 2    PO-19195  Phillina Ober  Home Office  United States  ...       60540
# 3    PO-19195  Phillina Ober  Home Office  United States  ...       60540
# 4    MB-18085     Mick Brown     Consumer  United States  ...       19143
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
# 3  Central  OFF-ST-10002743  Office Supplies      Storage
# 4     East  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448        2
# 1         GBC Standard Plastic Binding Systems Combs    3.540        2
# 2                                          Avery 508   11.784        3
# 3                      SAFCO Boltless Steel Shelving  272.736        3
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536        3
#
#    Discount   Profit
# 0       0.2   5.5512
# 1       0.8  -5.4870
# 2       0.2   4.2717
# 3       0.2 -64.7748
# 4       0.2   4.8840
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0  Row ID        Order ID  Order Date   Ship Date  \
# 10189       10189   10190  US-2026-143259  2026-12-30  2027-01-03
# 10190       10190   10191  US-2026-115427  2026-12-30  2027-01-03
# 10191       10191   10192  US-2026-156720  2026-12-30  2027-01-03
# 10192       10192   10193  US-2026-143259  2026-12-30  2027-01-03
# 10193       10193   10194  CA-2026-143500  2026-12-30  2027-01-03
#
#             Ship Mode Customer ID      Customer Name    Segment  \
# 10189  Standard Class    PO-18865  Patrick O'Donnell   Consumer
# 10190  Standard Class    EB-13975         Erica Bern  Corporate
# 10191  Standard Class    JM-15580      Jill Matthias   Consumer
# 10192  Standard Class    PO-18865  Patrick O'Donnell   Consumer
# 10193  Standard Class    HO-15230        Harry Olson   Consumer
#
#       Country/Region  ... Postal Code Region       Product ID  \
# 10189  United States  ...       10009   East  OFF-BI-10003684
# 10190  United States  ...       94533   West  OFF-BI-10004632
# 10191  United States  ...       80538   West  OFF-FA-10003472
# 10192  United States  ...       10009   East  TEC-PH-10004774
# 10193         Canada  ...         C0A   East  OFF-BI-10004040
#
#               Category Sub-Category                          Product Name  \
# 10189  Office Supplies      Binders  Wilson Jones Legal Size Ring Binders
# 10190  Office Supplies      Binders                    GBC Binding covers
# 10191  Office Supplies    Fasteners                   Bagged Rubber Bands
# 10192       Technology       Phones             Gear Head AU3700S Headset
# 10193  Office Supplies      Binders           Wilson Jones Impact Binders
#
#         Sales Quantity  Discount   Profit
# 10189  52.776        3       0.2  19.7910
# 10190  20.720        2       0.2   6.4750
# 10191   3.024        3       0.2  -0.6048
# 10192  90.930        7       0.0   2.7279
# 10193   3.024        3       0.2  -0.6048
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0        Row ID         Sales      Quantity      Discount  \
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5096.500000   5097.500000    228.225854      3.791838      0.155385
# std     2942.898656   2942.898656    619.906839      2.228317      0.206249
# min        0.000000      1.000000      0.444000      1.000000      0.000000
# 25%     2548.250000   2549.250000     17.220000      2.000000      0.000000
# 50%     5096.500000   5097.500000     53.910000      3.000000      0.200000
# 75%     7644.750000   7645.750000    209.500000      5.000000      0.200000
# max    10193.000000  10194.000000  22638.480000     14.000000      0.800000
#
#              Profit
# count  10194.000000
# mean      28.673417
# std      232.465115
# min    -6599.978000
# 25%        1.760800
# 50%        8.690000
# 75%       29.297925
# max     8399.976000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Row ID', 'Order ID', 'Order Date', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment',
#        'Country/Region', 'City', 'State/Province', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
sns.barplot(data=df, x="Category", y="Sales")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales") 

plt.show()

# %%
sns.barplot(data=df, x="Category", y="Profit")

plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit") 

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=df,
    x="Sub-Category",
    y="Profit"
)

plt.title("Profit by Sub-Category")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df, y="Sales")

plt.title("Sales Distribution")

plt.show()

# %%
sns.boxplot(data=df, y="Profit")

plt.title("Profit Distribution")

plt.show()

# %%
sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit"
)

plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")

plt.show()

# %%
discount_profit = df.groupby("Discount")["Profit"].mean()
discount_profit
# Out:
# Discount
# 0.00     66.338799
# 0.10     94.791354
# 0.15     27.288298
# 0.20     24.576350
# 0.30    -45.710633
# 0.32    -88.560656
# 0.40   -111.528378
# 0.45   -226.646464
# 0.50   -310.703456
# 0.60    -41.371458
# 0.70    -95.048521
# 0.80   -101.545745
# Name: Profit, dtype: float64

# %%
discount_profit.plot(kind="bar")

plt.title("Average Profit at Different Discount Levels")
plt.xlabel("Discount")
plt.ylabel("Average Profit")

plt.show()

# %%
numerical_data = df[
    ["Sales", "Quantity", "Discount", "Profit"]
]

correlation = numerical_data.corr()

sns.heatmap(correlation,annot=True,cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
region_profit = df.groupby("Region")["Profit"].sum()

print(region_profit)
# Out:
# Region
# Central     39865.3070
# East        94883.2603
# South       46749.4303
# West       110798.8170
# Name: Profit, dtype: float64

# %%
region_profit.plot(kind="bar")

plt.title("Total Profit by Region")
plt.xlabel("Region")
plt.ylabel("Profit")

plt.show()

# %%
category_data = df.groupby("Category")[["Sales", "Profit"]].sum()

print(category_data)
# Out:
#                        Sales       Profit
# Category
# Furniture        754747.7613   19729.9956
# Office Supplies  731893.3140  126023.4434
# Technology       839893.2790  146543.3756

# %%
category_data.plot(kind="bar")

plt.title("Sales and Profit by Category")
plt.xlabel("Category")
plt.ylabel("Amount")

plt.xticks(rotation=0)

plt.show()
